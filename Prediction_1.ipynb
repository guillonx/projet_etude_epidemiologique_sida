# %%
#Importation des bibliotheques

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [raw]
#  1- Les données

# %%
#importation des données

df= pd.read_csv("aids.csv",sep=';', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#           Pays   Année  mort_orphelin  mort_adulte  mort_toutAge  mort_enfant  \
# 0  Afghanistan  1990.0          100.0        100.0           500        100.0
# 1  Afghanistan  1991.0          100.0        100.0           500        100.0
# 2  Afghanistan  1992.0          100.0        100.0           500        100.0
# 3  Afghanistan  1993.0          200.0        100.0           600        100.0
# 4  Afghanistan  1994.0          200.0        100.0           600        100.0
#
#    mort_femmeAdulte  mort_hommeAdulte  \nprevalence_adulte  \
# 0             100.0             100.0                  0.1
# 1             100.0             100.0                  0.1
# 2             100.0             100.0                  0.1
# 3             100.0             100.0                  0.1
# 4             100.0             100.0                  0.1
#
#     \nPrevalence.jeuneHomme  ...  new_infection_hommeAdulte  \
# 0                       0.1  ...                      100.0
# ...

# %%
nb_row = df.shape[0]
print("nombre total de ligne:", nb_row )
# Out:
# nombre total de ligne: 2761

# %%
print("les colonnes de notre jeu de données:")
list(df)
# Out:
# les colonnes de notre jeu de données:
# ['Pays',
#  'Année',
#  'mort_orphelin',
#  'mort_adulte',
#  'mort_toutAge',
#  'mort_enfant',
#  'mort_femmeAdulte',
#  'mort_hommeAdulte',
#  '\nprevalence_adulte',
#  ' \nPrevalence.jeuneHomme',
#  ' \nPrevalence.jeuneFemme',
#  'new_infection_jeuneAdulte',
#  'new_infection_hommeAdulte',
#  'new_infection_femmeAdulte',
#  'new_infection_enfant',
#  'new_infection_toutAge',
#  'new_infection_Adulte',
#  'New_ Infection.\nIncidence_Rate_Among_Adults',
#  'personnes_vivant_avec.Total',
#  'adulte_homme_vivant_avec',
#  'adulte_femme_vivant_avec',
#  'enfant_vivant_avec']

# %%
 df.describe()
# Out:
#              Année  mort_orphelin    mort_adulte  mort_toutAge   mort_enfant  \
# count  2759.000000   2.759000e+03    2759.000000  2.761000e+03   2759.000000
# mean   2005.000000   1.042936e+05    7755.164915  1.223039e+05   2498.767669
# std       8.945893   2.437087e+05   18358.408671  2.785213e+05   5395.969671
# min    1990.000000   1.000000e+02     100.000000  0.000000e+00    100.000000
# 25%    1997.000000   1.200000e+03     200.000000  2.000000e+03    100.000000
# 50%    2005.000000   1.200000e+04    1100.000000  1.560000e+04    500.000000
# 75%    2013.000000   6.600000e+04    5000.000000  7.910000e+04   1700.000000
# max    2020.000000   1.800000e+06  220000.000000  2.075000e+06  49000.000000
#
#        mort_femmeAdulte  mort_hommeAdulte  \nprevalence_adulte  \
# count        2759.00000       2759.000000           2759.00000
# mean         4134.03407       3710.982240              2.60087
# std         10180.29161       8376.379071              5.01104
# ...

# %% [raw]
# 2- Nettoyage

# %%
df.info()
#on constate qu'il y'a des lignes vides dans notre jeu de données
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2761 entries, 0 to 2760
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Pays                                         2759 non-null   object
#  1   Année                                        2759 non-null   float64
#  2   mort_orphelin                                2759 non-null   float64
#  3   mort_adulte                                  2759 non-null   float64
#  4   mort_toutAge                                 2761 non-null   int64
#  5   mort_enfant                                  2759 non-null   float64
#  6   mort_femmeAdulte                             2759 non-null   float64
#  7   mort_hommeAdulte                             2759 non-null   float64
#  8
# prevalence_adulte                           2759 non-null   float64
#  9
# ...

# %%
# Pour voir les lignes vides
print(df.isnull().sum())
# Out:
# Pays                                            2
# Année                                           2
# mort_orphelin                                   2
# mort_adulte                                     2
# mort_toutAge                                    0
# mort_enfant                                     2
# mort_femmeAdulte                                2
# mort_hommeAdulte                                2
# \nprevalence_adulte                             2
#  \nPrevalence.jeuneHomme                        2
#  \nPrevalence.jeuneFemme                        2
# new_infection_jeuneAdulte                       2
# new_infection_hommeAdulte                       2
# new_infection_femmeAdulte                       2
# new_infection_enfant                            2
# new_infection_toutAge                           2
# new_infection_Adulte                            2
# New_ Infection.\nIncidence_Rate_Among_Adults    2
# personnes_vivant_avec.Total                     2
# ...

# %%
# pour supprimer toutes les ignes qui ont des colonnes vides
df = df.dropna(axis=0, how='any')

# %%
print(df.isnull().sum())
# Out:
# Pays                                            0
# Année                                           0
# mort_orphelin                                   0
# mort_adulte                                     0
# mort_toutAge                                    0
# mort_enfant                                     0
# mort_femmeAdulte                                0
# mort_hommeAdulte                                0
# \nprevalence_adulte                             0
#  \nPrevalence.jeuneHomme                        0
#  \nPrevalence.jeuneFemme                        0
# new_infection_jeuneAdulte                       0
# new_infection_hommeAdulte                       0
# new_infection_femmeAdulte                       0
# new_infection_enfant                            0
# new_infection_toutAge                           0
# new_infection_Adulte                            0
# New_ Infection.\nIncidence_Rate_Among_Adults    0
# personnes_vivant_avec.Total                     0
# ...

# %%
#Sélectionne les variables qu'on veut utiliser pour la prédiction
#Prévalence adulte = (Nombre total d'adultes vivant avec la maladie / Population adulte totale) x 100

X = df[['Année', 'mort_toutAge', 'new_infection_toutAge']]
y = df['\nprevalence_adulte']

# %%
# Créer un modèle de régression linéaire
lr_model = LinearRegression()

# %%
# Entraîner le modèle sur les données d'entraînement
lr_model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Faire des prédictions sur de nouvelles données
nouvelles_donnees = [[2022, 1000, 2000]]
prediction = lr_model.predict(nouvelles_donnees)

print(prediction)

#on observe qu'en 2022, il aura des personnes qui vivront avec la maladie
# Out:
# [1.56129335]
# C:\Users\dilan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# faire des prédictions pour chaque pays en 2022
X_2022 = ... # les données de prédiction pour 2022 pour chaque pays
y_pred_2022 = model.predict(X_2022)

# trouver le pays avec la valeur de mortalité la plus élevée
#max_mortality_country = data.loc[y_pred_2022.argmax(), 'Pays']
print("Le pays avec la valeur de mortalité la plus élevée en 2022 est : ", max_mortality_country)
# Out:
# C:\Users\dilan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19752\3315924601.py in <module>
#       1 # faire des prédictions pour chaque pays en 2022
#       2 X_2022 = ... # les données de prédiction pour 2022 pour chaque pays
# ----> 3 y_pred_2022 = model.predict(X_2022)
#       4
#       5 # trouver le pays avec la valeur de mortalité la plus élevée
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ...

# %%
# créer les ensembles d'entraînement et de test
X_train = df.drop(["Pays", "Année", "mort_toutAge"], axis=1)[:30] # les 30 premières années pour l'entraînement
y_train = df["mort_toutAge"][:30]
X_test = df.drop(["Pays", "Année", "mort_toutAge"], axis=1)[30:] # les années restantes pour le test
y_test = df["mort_toutAge"][30:]

# entraîner le modèle
model = LinearRegression()
model.fit(X_train, y_train)
# faire des prédictions pour chaque pays en 2022
X_2022 = df[df["Année"]==2022].drop(["Pays", "Année", "mort_toutAge"], axis=1)
y_pred_2022 = model.predict(X_2022)

# trouver le pays avec la valeur de mortalité la plus élevée
pays_plus_de_morts_2022 = df.loc[df["Année"]==2022].iloc[y_pred_2022.argmax()]["Pays"]
print("Le pays avec la valeur de mortalité la plus élevée en 2022 est : ", pays_plus_de_morts_2022)

# %%
X = df.drop(["Pays", "Année", "mort_toutAge"], axis=1) # variables indépendantes
y = df["mort_toutAge"] # variable dépendante
model = LinearRegression().fit(X, y)

# %%
X_2022 = df[df["Année"]==2022].drop(["Pays", "Année", "mort_toutAge"], axis=1) # les données de prédiction pour 2022 pour chaque pays
y_pred_2022 = model.predict(X_2022)

# %%
df.groupby(['Année', 'Pays'])['mort_toutAge'].idxmax()

# %%
df = df[df["Année"] <= 2020]

# %%
X = df.drop(["Pays", "Année", "mort_toutAge"], axis=1)
y = df["mort_toutAge"]

# %%
X = df.drop(["Pays", "Année", "mort_toutAge"], axis=1)
y = df["mort_toutAge"]

# %%
X_2022 = df[df["Année"]==2022].drop(["Pays", "Année", "mort_toutAge"], axis=1)

# %%
#y_pred_2022 = model.predict(X_2022)

# %%
print(X_2022.shape)

# %%
df.groupby(['Année', 'Pays'])['mort_toutAge'].idxmax()

# %%
df[df["Année"]==2020].sort_values("mort_toutAge", ascending=False).iloc[0]["Pays"]

# %%
X = df[['Année', 'mort_toutAge', 'new_infection_toutAge']]
y = df['\nprevalence_adulte']
lr_model = LinearRegression()
lr_model.fit(X, y)
nouvelles_donnees = [[2022, 1000, 2000]]
prediction = lr_model.predict(nouvelles_donnees)

print(prediction)
